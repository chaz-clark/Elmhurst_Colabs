# %% [markdown]
# Start R:

# %%
cat(system('python3 -c "from google.colab import drive\ndrive.mount()"', intern=TRUE), sep='\n', wait=TRUE)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `system'
# /bin/bash: -c: line 0: `cat (system('python3 -c "from google.colab import drive\ndrive.mount()"', intern=TRUE), sep='\n', wait=TRUE)'

# %%
# ?system

# %%
install.packages("rgl", repos = "http://cran.rstudio.com/")
install.packages("ConsRank", repos = "http://cran.rstudio.com/")
library("ConsRank")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b36284337772> in <module>()
# ----> 1 install.packages("rgl", repos = "http://cran.rstudio.com/")
#       2 install.packages("ConsRank", repos = "http://cran.rstudio.com/")
#       3 library("ConsRank")
#
# NameError: name 'install' is not defined

# %%
system("add-apt-repository -y ppa:marutter/rrutter")
system("add-apt-repository -y ppa:marutter/c2d4u")
system("apt-get update")
system("apt install -y r-cran-rstan")

# %%
nstall.packages('ggmap')
install.packages('codetools')

# %%
library("ggmap")

# %%
options(repr.plot.width  = 3,
        repr.plot.height = 3)
Sys.setenv(USE_CXX14 = 1)
library("rstan") # observe startup messages
options(mc.cores = parallel::detectCores())
rstan_options(auto_write = TRUE)

# %% [markdown]
# Test R works:

# %%
x <- seq(0, 2*pi, length.out=50)
plot(x, sin(x))
